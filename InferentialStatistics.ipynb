# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Load the dataset
data = pd.read_csv('Practice.csv')

# %%
data.head(8)
# Out:
#   treatment stone_size  success
# 0         B      large        1
# 1         A      large        1
# 2         A      large        0
# 3         A      large        1
# 4         A      large        1
# 5         B      large        1
# 6         A      small        1
# 7         B      large        1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['success'].plot(kind='hist', bins=20, title='success')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('treatment').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
print("Column name:")
print(data.columns)

print("\nData type: ")
print(data.dtypes)

print("\nDescribe data:")
print(data.describe)
# Out:
# Column name:
# Index(['treatment', 'stone_size', 'success'], dtype='object')
#
# Data type:
# treatment     object
# stone_size    object
# success        int64
# dtype: object
#
# Describe data:
# <bound method NDFrame.describe of     treatment stone_size  success
# 0           B      large        1
# 1           A      large        1
# 2           A      large        0
# 3           A      large        1
# 4           A      large        1
# ..        ...        ...      ...
# 695         B      small        0
# 696         B      small        1
# 697         B      small        1
# 698         A      large        1
# 699         A      small        1
#
# [700 rows x 3 columns]>
